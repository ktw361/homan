# %%
from pathlib import Path
import os, pickle
import os.path as osp
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import torch
import libyana, manopth

# %%
ho3d = Path('/media/deepthought/DATA/Zhifan/HO3D_v2')
abf10 = osp.join(ho3d, 'train/ABF10')
depth = osp.join(abf10, 'depth/0000.png')
meta = osp.join(abf10, 'meta/0000.pkl')
rgb = osp.join(abf10, 'rgb/0000.png')

# %%
split = 'evaluation'
print(sorted(os.listdir(ho3d/split)))
# Out:
# ['AP10', 'AP11', 'AP12', 'AP13', 'AP14', 'MPM10', 'MPM11', 'MPM12', 'MPM13', 'MPM14', 'SB11', 'SB13', 'SM1']

# %%
name = 'SB11'
host = ho3d/split/name/'rgb'

img = np.random.choice(os.listdir(host))
Image.open(host/img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=640x480 at 0x7F396E5DC790>
